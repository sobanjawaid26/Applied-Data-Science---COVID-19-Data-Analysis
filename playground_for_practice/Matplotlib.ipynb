# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3],[4,5,1])

# %%
x= [5,8,10]
y = [12,16,6]

# %%
plt.title('Info')
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.show()

# %%
plt.plot(x, y)

# %%
plt.show()
